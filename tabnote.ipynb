# %%
from PIL import Image
import matplotlib.pyplot as plt

# Read the image
image = Image.open("money heist.jpeg")

# Display the image
plt.imshow(image)
plt.axis('off') # Hide axes
plt.show()

# %%
from PIL import Image

# Read the image
image = Image.open('money heist.jpeg')

# Display the image
image.show()

# Save the image
image.save('image.jpeg')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('money heist.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply simple thresholding
threshold_value = 127  # You can adjust this value
_, thresholded_image = cv2.threshold(image, threshold_value, 255, cv2.THRESH_BINARY)

# Display the original and thresholded images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Thresholded Image')
plt.imshow(thresholded_image, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('money heist.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply adaptive thresholding
adaptive_thresh_mean = cv2.adaptiveThreshold(
    image, 
    255, 
    cv2.ADAPTIVE_THRESH_MEAN_C, 
    cv2.THRESH_BINARY, 
    11, 2
)

adaptive_thresh_gaussian = cv2.adaptiveThreshold(
    image, 
    255, 
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
    cv2.THRESH_BINARY, 
    11, 2
)

# Display the original and thresholded images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Adaptive Mean Thresholding')
plt.imshow(adaptive_thresh_mean, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Adaptive Gaussian Thresholding')
plt.imshow(adaptive_thresh_gaussian, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('money heist.jpeg', cv2.IMREAD_GRAYSCALE)

# Apply Otsu's thresholding
_, otsu_thresholded_image = cv2.threshold(
    image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU
)

# Display the original and thresholded images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Otsu Thresholding')
plt.imshow(otsu_thresholded_image, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('money heist.jpeg', cv2.IMREAD_GRAYSCALE)

# Define the threshold value
threshold_value = 127  # You can adjust this value

# Apply binary thresholding
_, binary_thresholded_image = cv2.threshold(
    image, threshold_value, 255, cv2.THRESH_BINARY
)

# Display the original and thresholded images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Binary Thresholding')
plt.imshow(binary_thresholded_image, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the images
image1 = cv2.imread('money heist 3.jpg')
image2 = cv2.imread('money heist 4.jpg')

# Convert images to grayscale if they are in color
image1_gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
image2_gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# Ensure images are the same size
if image1_gray.shape != image2_gray.shape:
    raise ValueError("Images must be of the same size")

# Perform image addition
added_image = cv2.add(image1_gray, image2_gray)

# Display the original and added images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Image 1')
plt.imshow(image1_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Image 2')
plt.imshow(image2_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Added Image')
plt.imshow(added_image, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the images
image1 = cv2.imread('money heist 3.jpg')
image2 = cv2.imread('money heist 4.jpg')

# Convert images to grayscale if they are in color
image1_gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
image2_gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# Ensure images are the same size
if image1_gray.shape != image2_gray.shape:
    raise ValueError("Images must be of the same size")

# Perform image subtraction
subtracted_image = cv2.subtract(image1_gray, image2_gray)

# Display the original and subtracted images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Image 1')
plt.imshow(image1_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Image 2')
plt.imshow(image2_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Subtracted Image')
plt.imshow(subtracted_image, cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the images
image1 = cv2.imread('money heist 3.jpg')
image2 = cv2.imread('money heist 4.jpg')

# Convert images to grayscale if they are in color
image1_gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
image2_gray = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# Ensure images are the same size
if image1_gray.shape != image2_gray.shape:
    raise ValueError("Images must be of the same size")

# Perform bitwise AND operation
bitwise_and_image = cv2.bitwise_and(image1_gray, image2_gray)

# Perform bitwise OR operation
bitwise_or_image = cv2.bitwise_or(image1_gray, image2_gray)

# Display the original and result images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Image 1')
plt.imshow(image1_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Image 2')
plt.imshow(image2_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Bitwise AND & OR')
plt.imshow(np.hstack([bitwise_and_image, bitwise_or_image]), cmap='gray')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve2d

# Load the image
image = cv2.imread('money heist 4.jpg', cv2.IMREAD_GRAYSCALE)

# Define a kernel (e.g., a simple blur kernel for demonstration)
kernel = np.array([[1, 1, 1],
                   [1, 1, 1],
                   [1, 1, 1]], dtype=np.float32)
kernel /= kernel.sum()

# Apply the kernel to the image
blurred_image = convolve2d(image, kernel, mode='same', boundary='wrap')

# Simple Wiener deconvolution (approximate)
def wiener_deconv(blurred, kernel, noise_var):
    kernel_ft = np.fft.fft2(kernel, s=blurred.shape)
    blurred_ft = np.fft.fft2(blurred)
    kernel_ft_conj = np.conj(kernel_ft)
    result_ft = (blurred_ft * kernel_ft_conj) / (np.abs(kernel_ft)**2 + noise_var)
    result = np.fft.ifft2(result_ft)
    return np.abs(result)

# Deblur the image
deblurred_image = wiener_deconv(blurred_image, kernel, 0.01)

# Display the original, blurred, and deblurred images
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.title('Blurred Image')
plt.imshow(blurred_image, cmap='gray')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.title('Deblurred Image')
plt.imshow(deblurred_image, cmap='gray')
plt.axis('off')

plt.show()
